# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/EDCO_IntroCienciaDatos/blob/main/Semana2/Sesion3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# sistema operativo
import os

# %%
# llamar un camando de unix,linux. Directorio actual
# Comandos de ubicacion
# !pwd
# Out:
# /content

# %%
"listar el contenido en la carpeta"
# !ls
# Out:
# drive  sample_data

# %%
# Movernos de carpeta
ruta = "/content/drive/MyDrive/EDCO_IntroCienciaDatos/Semana2"
os.chdir(ruta)

# %%
# !ls
# Out:
# BaseDatos  Carpeta_salida  Datos  Sesion3.ipynb

# %%
# Vamos a crear la carpeta de salida
salida = "Carpeta_salida"
os.makedirs(salida,exist_ok=True)

# %%
# !pwd
# Out:
# /content/drive/MyDrive/EDCO_IntroCienciaDatos/Semana2

# %%
#os.chdir(salida)

# %%
# !pwd
# Out:
# /content/drive/MyDrive/EDCO_IntroCienciaDatos/Semana2

# %%
# Como creamos 40 carpetas en la carpeta de salida????
for i in range(1,41):
  subcarpeta = 'sub_{}'.format(i)

  print('Creando carpeta:', subcarpeta)
  os.makedirs(subcarpeta, exist_ok = True)
# Out:
# Creando carpeta: sub_1
# Creando carpeta: sub_2
# Creando carpeta: sub_3
# Creando carpeta: sub_4
# Creando carpeta: sub_5
# Creando carpeta: sub_6
# Creando carpeta: sub_7
# Creando carpeta: sub_8
# Creando carpeta: sub_9
# Creando carpeta: sub_10
# Creando carpeta: sub_11
# Creando carpeta: sub_12
# Creando carpeta: sub_13
# Creando carpeta: sub_14
# Creando carpeta: sub_15
# Creando carpeta: sub_16
# Creando carpeta: sub_17
# Creando carpeta: sub_18
# Creando carpeta: sub_19
# Creando carpeta: sub_20
# Creando carpeta: sub_21
# Creando carpeta: sub_22
# Creando carpeta: sub_23
# Creando carpeta: sub_24
# Creando carpeta: sub_25
# Creando carpeta: sub_26
# Creando carpeta: sub_27
# Creando carpeta: sub_28
# Creando carpeta: sub_29
# Creando carpeta: sub_30
# Creando carpeta: sub_31
# Creando carpeta: sub_32
# Creando carpeta: sub_33
# Creando carpeta: sub_34
# Creando carpeta: sub_35
# Creando carpeta: sub_36
# Creando carpeta: sub_37
# Creando carpeta: sub_38
# ...

# %%
# Veamos nuestras bases
BaseDatos = {
    101: {'Nombre':'Andres','Apellido':'Trujillo','Edad': 35,'Genero': 'M' },
    102: {'Nombre':'Diana','Apellido':'Henao','Edad': 25,'Genero': 'F' },
    103: {'Nombre':'Javier','Apellido':'Bastidas','Edad': 22,'Genero': 'M' }
}

# %%
#Primer dataframe
df = pd.DataFrame.from_dict(BaseDatos,orient='index')
df
# Out:
#      Nombre  Apellido  Edad Genero
# 101  Andres  Trujillo    35      M
# 102   Diana     Henao    25      F
# 103  Javier  Bastidas    22      M

# %%
df.loc[101] # Una ejecución de consulta
# Out:
# Nombre        Andres
# Apellido    Trujillo
# Edad              35
# Genero             M
# Name: 101, dtype: object

# %%
# Elegir una columna de los datos
df['Edad']
# Out:
# 101    35
# 102    25
# 103    22
# Name: Edad, dtype: int64

# %%
# Pandas basico
df.index.name = 'ID'
df
# Out:
#      Nombre  Apellido  Edad Genero
# ID
# 101  Andres  Trujillo    35      M
# 102   Diana     Henao    25      F
# 103  Javier  Bastidas    22      M

# %%
# POdemos convertir el ID en una columna
df = df.reset_index()
df
# Out:
#     ID  Nombre  Apellido  Edad Genero
# 0  101  Andres  Trujillo    35      M
# 1  102   Diana     Henao    25      F
# 2  103  Javier  Bastidas    22      M

# %%
# Visualizar los dataframe
df.head(2)
# Out:
#     ID  Nombre  Apellido  Edad Genero
# 0  101  Andres  Trujillo    35      M
# 1  102   Diana     Henao    25      F

# %%
# La dimension de la matriz
df.shape
# Out:
# (3, 5)

# %%
df
# Out:
#     ID  Nombre  Apellido  Edad Genero
# 0  101  Andres  Trujillo    35      M
# 1  102   Diana     Henao    25      F
# 2  103  Javier  Bastidas    22      M

# %%
# Como consultamos el nombre las columnas
df.keys()
# Out:
# Index(['ID', 'Nombre', 'Apellido', 'Edad', 'Genero'], dtype='object')

# %%
df.columns
# Out:
# Index(['ID', 'Nombre', 'Apellido', 'Edad', 'Genero'], dtype='object')

# %%
# Consultar los tipos
df.dtypes
# Out:
# ID           int64
# Nombre      object
# Apellido    object
# Edad         int64
# Genero      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        3 non-null      int64
#  1   Nombre    3 non-null      object
#  2   Apellido  3 non-null      object
#  3   Edad      3 non-null      int64
#  4   Genero    3 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 252.0+ bytes

# %%
df.describe()
# Out:
#           ID       Edad
# count    3.0   3.000000
# mean   102.0  27.333333
# std      1.0   6.806859
# min    101.0  22.000000
# 25%    101.5  23.500000
# 50%    102.0  25.000000
# 75%    102.5  30.000000
# max    103.0  35.000000

# %%
# Quremos escoger unas columnas especificas
df1 = df[['Edad','Genero']]
df1
# Out:
#    Edad Genero
# 0    35      M
# 1    25      F
# 2    22      M

# %%
# Aplicar mascarcaras "masking" o filtros
# Personas mayores a 25
mask = df['Edad'] >= 25 # Esto es una condición
mask
# Out:
# 0     True
# 1     True
# 2    False
# Name: Edad, dtype: bool

# %%
df2 = df[mask]
df2
# Out:
#     ID  Nombre  Apellido  Edad Genero
# 0  101  Andres  Trujillo    35      M
# 1  102   Diana     Henao    25      F

# %%
mask2 = df['Genero'] == 'M'
mask2
# Out:
# 0     True
# 1    False
# 2     True
# Name: Genero, dtype: bool

# %%
df3 = df[mask2]
df3
# Out:
#     ID  Nombre  Apellido  Edad Genero
# 0  101  Andres  Trujillo    35      M
# 2  103  Javier  Bastidas    22      M

# %%
df
# Out:
#     ID  Nombre  Apellido  Edad Genero
# 0  101  Andres  Trujillo    35      M
# 1  102   Diana     Henao    25      F
# 2  103  Javier  Bastidas    22      M

# %%
# filtro es que tenga 25 años o más
# filtro es que sea del genero masculino
df[mask & mask2]
# Out:
#     ID  Nombre  Apellido  Edad Genero
# 0  101  Andres  Trujillo    35      M

# %%
df[mask | mask2]
# Out:
#     ID  Nombre  Apellido  Edad Genero
# 0  101  Andres  Trujillo    35      M
# 1  102   Diana     Henao    25      F
# 2  103  Javier  Bastidas    22      M

# %%
# Como consultamos una entrada en particular
df.loc[1]
# Out:
# ID            102
# Nombre      Diana
# Apellido    Henao
# Edad           25
# Genero          F
# Name: 1, dtype: object

# %%
# Tomar una porción del dato, estilo algebra lineal
df.iloc[1,:] # segunda fila -> todas las columnas
# Out:
# ID            102
# Nombre      Diana
# Apellido    Henao
# Edad           25
# Genero          F
# Name: 1, dtype: object

# %%
df.iloc[:2,2:4] # Slicing
# Out:
#    Apellido  Edad
# 0  Trujillo    35
# 1     Henao    25

# %%
df[['Nombre','Genero']].iloc[:2,:]
# Out:
#    Nombre Genero
# 0  Andres      M
# 1   Diana      F

# %%
# !pwd
# Out:
# /content/drive/MyDrive/EDCO_IntroCienciaDatos/Semana2

# %%
#
df.to_csv('personal.csv')

# %%
os.chdir('Carpeta_salida')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_20013/1724322217.py in <cell line: 0>()
# ----> 1 os.chdir('Carpeta_salida')
#       2 get_ipython().system('pwd')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Carpeta_salida'

# %%
# !pwd
# Out:
# /content/drive/MyDrive/EDCO_IntroCienciaDatos/Semana2/Carpeta_salida

# %%
# !ls
# Out:
# sub_1	sub_13	sub_17	sub_20	sub_24	sub_28	sub_31	sub_35	sub_39	sub_6
# sub_10	sub_14	sub_18	sub_21	sub_25	sub_29	sub_32	sub_36	sub_4	sub_7
# sub_11	sub_15	sub_19	sub_22	sub_26	sub_3	sub_33	sub_37	sub_40	sub_8
# sub_12	sub_16	sub_2	sub_23	sub_27	sub_30	sub_34	sub_38	sub_5	sub_9

# %%
print('sub_{:.0f}'.format(100))
# Out:
# sub_100

# %%
# !pwd
# Out:
# /content/drive/MyDrive/EDCO_IntroCienciaDatos/Semana2/Carpeta_salida

# %%
df['Edad'].plot(kind='bar')
plt.savefig('edad.png')

# %%
# Como grabamos los datos en cada sub-carpeta
for i in range(1,41):

  subcarpeta = 'moviendonos a sub_{}'.format(i)

  os.chdir('sub_{}'.format(i))
  #!pwd

  print('Imprimiendo el histograma de la edad en sub_{}'.format(i))
  df['Edad'].plot(kind='bar')
  plt.savefig('edad.png')

  # Imprimir la ficha tecnica
  df.to_csv('personal.csv')

  # Cambiar a la carpeta principal
  os.chdir('/content/drive/MyDrive/EDCO_IntroCienciaDatos/Semana2/Carpeta_salida')
# Out:
# Imprimiendo el histograma de la edad en sub_1
# Imprimiendo el histograma de la edad en sub_2
# Imprimiendo el histograma de la edad en sub_3
# Imprimiendo el histograma de la edad en sub_4
# Imprimiendo el histograma de la edad en sub_5
# Imprimiendo el histograma de la edad en sub_6
# Imprimiendo el histograma de la edad en sub_7
# Imprimiendo el histograma de la edad en sub_8
# Imprimiendo el histograma de la edad en sub_9
# Imprimiendo el histograma de la edad en sub_10
# Imprimiendo el histograma de la edad en sub_11
# Imprimiendo el histograma de la edad en sub_12
# Imprimiendo el histograma de la edad en sub_13
# Imprimiendo el histograma de la edad en sub_14
# Imprimiendo el histograma de la edad en sub_15
# Imprimiendo el histograma de la edad en sub_16
# Imprimiendo el histograma de la edad en sub_17
# Imprimiendo el histograma de la edad en sub_18
# Imprimiendo el histograma de la edad en sub_19
# Imprimiendo el histograma de la edad en sub_20
# ...

# %%
# Queremos grabar la grafica en las 41 carpetas ???
