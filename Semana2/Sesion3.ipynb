# %% [markdown]
# <a href="https://colab.research.google.com/github/asegura4488/EDCO_IntroCienciaDatos/blob/main/Semana2/Sesion3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# sistema operativo
import os

# %%
# llamar un camando de unix,linux. Directorio actual
# Comandos de ubicacion
# !pwd
# Out:
# /content

# %%
"listar el contenido en la carpeta"
# !ls
# Out:
# drive  sample_data

# %%
# Movernos de carpeta
ruta = "/content/drive/MyDrive"
os.chdir(ruta)

# %%
# !ls
# Out:
#  armario_lore.zip
#  CharlasMetodos
#  ColabNotebooks
#  Covid19.csv
#  Cuantica_AlonsoBotero
#  Denuncia
# 'Deuda Alejandro Segura.gsheet'
#  EDCO_IntroCienciaDatos
#  EDCO_MachineLearning
#  IMG_20260922_104258_833.jpg
# 'IMG_20260922_104312_859 (1).jpg'
#  IMG_20260922_104312_859.jpg
#  Information
#  Javeriana
#  LED
#  MetodosComputacionales_Antiguo
#  miguel.mp4
#  OficioPeticionEspecial_ManuelAlejandroSegura1015403960.pdf
#  PAPERSUAREZ
#  PresentacionDoctorado.m4a
#  Proyecto_FisicaA
#  ProyectoMalaria
#  RutinaAjuste
#  Santi_Fotos
#  SantiMatricula
#  UMilitar
